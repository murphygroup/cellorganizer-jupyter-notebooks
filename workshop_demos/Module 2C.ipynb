# %% [markdown]
# <h1> Module 2C</h1>

# %%
from cellorganizer.tools import slml2report
import glob
import urllib.request
import tarfile 
import os
from IPython.core.display import display, HTML, Image

folder_name = 'Module2C'
model_name = 'Module2A1vsModule2A4'
model_folder = "/home/murphylab/cellorganizer/local/models/3D/SPHARM-RPDM/"

topdir = "/home/murphylab/cellorganizer/local/results"
outputdir = topdir + "/" + folder_name
if not os.path.exists(topdir):
    os.makedirs(topdir)
os.chdir(topdir)
os.system("ls")
if not os.path.exists(outputdir):
    os.makedirs(outputdir)
os.chdir(outputdir)
os.system("ls")
if not os.path.exists(model_name):
    os.makedirs(model_name)
os.chdir(model_name)
os.system("ls")

options = {}
options['shape_evolution'] = 'null'
options['labels'] = 'unique'
options['subsize'] = 400 #controls the size of the shape (larger number is smaller)
options['includeprot'] = 'true'

model_files_1 = model_folder + 'Module2A1.mat'
model_files_2 = model_folder + 'Module2A4.mat'
os.system("ls")
answer = slml2report(model_files_1 , model_files_2, options)
HTML(filename =  'index.html')
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filenames</h2>
# <p>model1_filename = /home/murphylab/cellorganizer/local/models/3D/SPHARM-RPDM/Module2A1.mat</p>model2_filename = /home/murphylab/cellorganizer/local/models/3D/SPHARM-RPDM/Module2A4.mat
# <h2>Model Identifiers</h2>
# <p>model1.filename = Module2A1.mat;model1.name = Module2A1;model1.id = 58BDB6DF-4745-4465-A2FE-24D52CECE08D;</p><p>model2.filename = Module2A4.mat;model2.name = Module2A4;model2.id = A87B3756-EEDD-4C73-B6D6-3104711A784D;</p>
# <figure>
# <a href="show_shape_space.png"><img src="show_shape_space_thumbnail.png" /></a>
# <figcaption>Joint shape space from SPRM-RPDM models.</figcaption>
# </figure>
#
# </body>
# </html>

# %%
Image('show_shape_space.png')
