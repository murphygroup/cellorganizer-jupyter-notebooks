# %% [markdown]
# ## Module 2C
# ## Tutorial 2 covers generating SPHARM-RPDM models, creating reports from models, and comparing models.
# ## Module 2C compares the two models created in Module 2A.  There are examples of the two models in the distributed 'models' folder so Module 2A can be skipped to save time.
#
# ### Run the cell below to set up basic parameters:

# %%
from cellorganizer.tools import slml2report
import glob
import urllib.request
import tarfile 
import os
from IPython.core.display import display, HTML, Image

folder_name = 'Module2C'

topdir = "/home/murphylab/cellorganizer/local/results"
outputdir = topdir + "/" + folder_name
if not os.path.exists(topdir):
    os.makedirs(topdir)
os.chdir(topdir)
if not os.path.exists(outputdir):
    os.makedirs(outputdir)
os.chdir(outputdir)

options = {}
options['shape_evolution'] = 'null'
options['labels'] = 'unique'
options['subsize'] = 400 #controls the size of the shape (larger number is smaller)
options['includenuclear'] = 0
options['paired'] = 0

model_folder = "/home/murphylab/cellorganizer/local/models/"
model_files_1 = model_folder + 'Module2A1.mat'
model_files_2 = model_folder + 'Module2A2.mat'
# Uncomment the two lines below if you want to use the ones you created using Module 2A
#model_files_1 = '/home/murphylab/cellorganizer/local/results/Module2A/Module2A1.mat'
#model_files_2 = '/home/murphylab/cellorganizer/local/results/Module2A/Module2A2.mat'

answer = slml2report(model_files_1 , model_files_2, options)
HTML(filename =  'index.html')
# Out:
# CellOrganizer v2.10 (MATLAB RO2019a)
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filenames</h2>
# <p>model1_filename = /home/murphylab/cellorganizer/local/models/Module2A1.mat</p>model2_filename = /home/murphylab/cellorganizer/local/models/Module2A2.mat
# <h2>Model Identifiers</h2>
# <p>model1.filename = model.xml;model1.name = unset;model1.id = 123;</p><p>model2.filename = model.xml;model2.name = unset;model2.id = 234;</p>
# <h2>SPHARM-RPMD Cell Shape Model Comparison</h2>
# <p>Number of cells: Model 1 9; Model 2 9</p>
# </body>
# </html>

# %%
Image('show_shape_space_1.png')
