# %%
from cellorganizer.tools import slml2report
import glob
import urllib.request
import tarfile 
import os
from IPython.core.display import display, HTML, Image

folder_name = 'Module4B'
model_name = 'synthetic_golgi_model_vs_real_golgi_model'
model_folder = "/home/murphylab/cellorganizer/local/models/"

topdir = "/home/murphylab/cellorganizer/local/results"
outputdir = topdir + "/" + folder_name
if not os.path.exists(topdir):
    os.makedirs(topdir)
os.chdir(topdir)
os.system("ls")
if not os.path.exists(outputdir):
    os.makedirs(outputdir)
os.chdir(outputdir)
os.system("ls")
if not os.path.exists(model_name):
    os.makedirs(model_name)
os.chdir(model_name)
os.system("ls")

options = {}
options['verbose'] = 1
options['includenuclear'] = 0
options['includecell'] = 0
options['includeprot'] = 1
options['paired'] = 0

# %% [markdown]
# * Compare the golgi appratus model trained by real microscopy images and synthetic images generated by a deep generative model

# %%
model_files_1 = model_folder + 'golgi_vox2vox_model_s.mat'
model_files_2 = model_folder + 'golgi_GT_model_s.mat'
os.system("ls")
answer = slml2report(model_files_1 , model_files_2, options)
HTML(filename =  'index.html')

# visualize them
# Out:
# CellOrganizer v2.10 (MATLAB RO2019a)
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filenames</h2>
# <p>model1_filename = /home/murphylab/cellorganizer/local/models/golgi_vox2vox_model_s.mat</p>model2_filename = /home/murphylab/cellorganizer/local/models/golgi_GT_model_s.mat
# <h2>Model Identifiers</h2>
# <p>model1.filename = model.xml;model1.name = spharm_obj;model1.id = golgi synthetic image;</p><p>model2.filename = model.xml;model2.name = spharm_obj;model2.id = golgi real microscopy;</p>
# <h2>Spharm Model Comparison</h2>
#
# <figure>
# <a href="show_shape_space_1.png"><img src="show_shape_space_1_thumbnail.png" /></a>
# <figcaption>Joint shape space from SPRM-RPDM models.</figcaption>
# </figure>
#
# <p>Shape space comparison score between model1 and model2: 0.0792;
# </p><p>P value of shape space comparison score: 0.1400;
# </p>
# <h2>Spatial Model Comparison</h2>
# <p>Spatial distribution comparison score between model1 and model2: 0.0326;
# </p>
# <figure>
# <a href="show_spatial_distribution.png"><img src="show_spatial_distribution_thumbnail.png" /></a>
# <figcaption>Spatial Distribution across both models</figcaption>
# </figure>
#
#
# <figure>
# <a href="spatial_model_fit.png"><img src="spatial_model_fit_thumbnail.png" /></a>
# <figcaption>Spatial Probability Distribution fitted to a Gaussian Kernel</figcaption>
# </figure>
#
#
# <figure>
# <a href="spatial_model_diff.png"><img src="spatial_model_diff_thumbnail.png" /></a>
# <figcaption>Difference in Spatial Probability Distribution between 2 Models fitted to a Gaussian Kernel</figcaption>
# </figure>
#
# <p>KL divergence between spatial distributions of model1 and model2: 0.0242;
# </p><p>P value of hape spatial distribution divergence: 1.0000;
# </p><p>R2: 0.0949;
# </p></body>
# </html>

# %%
Image('show_shape_space_1.png')

# %%
Image('show_spatial_distribution.png')

# %%
Image('spatial_model_fit.png')

# %%
Image('spatial_model_diff.png')

# %% [markdown]
# * Compare the nucleoli model trained by real microscopy images and synthetic images generated by a deep generative model

# %%
model_name = 'synthetic_nucleoli_model_vs_real_nucleoli_model'

topdir = "/home/murphylab/cellorganizer/local/results"
outputdir = topdir + "/" + folder_name
if not os.path.exists(topdir):
    os.makedirs(topdir)
os.chdir(topdir)
os.system("ls")
if not os.path.exists(outputdir):
    os.makedirs(outputdir)
os.chdir(outputdir)
os.system("ls")
if not os.path.exists(model_name):
    os.makedirs(model_name)
os.chdir(model_name)
os.system("ls")


model_files_1 = model_folder + 'nucleoli_vox2vox_model_s.mat'
model_files_2 = model_folder + 'nucleoli_GT_model_s.mat'
os.system("ls")
answer = slml2report(model_files_1 , model_files_2, options)
HTML(filename =  'index.html')

# visualize them
# Out:
# CellOrganizer v2.10 (MATLAB RO2019a)
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filenames</h2>
# <p>model1_filename = /home/murphylab/cellorganizer/local/models/nucleoli_vox2vox_model_s.mat</p>model2_filename = /home/murphylab/cellorganizer/local/models/nucleoli_GT_model_s.mat
# <h2>Model Identifiers</h2>
# <p>model1.filename = model.xml;model1.name = spharm_obj;model1.id = nucleoli synthetic image;</p><p>model2.filename = model.xml;model2.name = spharm_obj;model2.id = nucleoli real microscopy;</p>
# <h2>Spharm Model Comparison</h2>
#
# <figure>
# <a href="show_shape_space_1.png"><img src="show_shape_space_1_thumbnail.png" /></a>
# <figcaption>Joint shape space from SPRM-RPDM models.</figcaption>
# </figure>
#
# <p>Shape space comparison score between model1 and model2: 0.0538;
# </p><p>P value of shape space comparison score: 0.4000;
# </p>
# <h2>Spatial Model Comparison</h2>
# <p>Spatial distribution comparison score between model1 and model2: 0.0278;
# </p>
# <figure>
# <a href="show_spatial_distribution.png"><img src="show_spatial_distribution_thumbnail.png" /></a>
# <figcaption>Spatial Distribution across both models</figcaption>
# </figure>
#
#
# <figure>
# <a href="spatial_model_fit.png"><img src="spatial_model_fit_thumbnail.png" /></a>
# <figcaption>Spatial Probability Distribution fitted to a Gaussian Kernel</figcaption>
# </figure>
#
#
# <figure>
# <a href="spatial_model_diff.png"><img src="spatial_model_diff_thumbnail.png" /></a>
# <figcaption>Difference in Spatial Probability Distribution between 2 Models fitted to a Gaussian Kernel</figcaption>
# </figure>
#
# <p>KL divergence between spatial distributions of model1 and model2: 0.0088;
# </p><p>P value of hape spatial distribution divergence: 0.9600;
# </p><p>R2: 0.1290;
# </p></body>
# </html>

# %%
Image('show_shape_space_1.png')

# %%
Image('show_spatial_distribution.png')

# %%
Image('spatial_model_fit.png')

# %%
Image('spatial_model_diff.png')

# %% [markdown]
# * For more details, please refer to our [paper](https://www.biorxiv.org/content/10.1101/2022.05.24.493229v1.abstract).
