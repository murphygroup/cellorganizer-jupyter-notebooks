# %% [markdown]
# ## Module 2B
# ## Tutorial 2 covers generating SPHARM-RPDM models, creating reports from models, and comparing models.
# ## Module 2B generates reports on the models generated by Module 2A. There are copies of the two models in the distributed 'models' folder so Module 2A can be skipped to save time.
# ### Run the cell below to set up basic parameters:

# %% [markdown]
# <h3> Part 1</h3>

# %%
from cellorganizer.tools import slml2info
import os
import urllib.request
import tarfile 
import os
from IPython.core.display import display, HTML, Image

folder_name = 'Module2B'
model_name = 'Module2A1'
model_file = "/home/murphylab/cellorganizer/local/models/" +  model_name + ".mat"
# optionally, change to read the version of the model files in the results directory of Module 2A 
#model_file = "/home/murphylab/cellorganizer/local/results/Module2A/" +  model_name + ".mat"

topdir = "/home/murphylab/cellorganizer/local/results"
outputdir = topdir + os.path.sep + folder_name
if not os.path.exists(topdir):
    os.makedirs(topdir)
os.chdir(topdir)
os.system("ls")
if not os.path.exists(outputdir):
    os.makedirs(outputdir)
os.chdir(outputdir)
os.system("ls")
if not os.path.exists(model_name):
    os.makedirs(model_name)
os.chdir(model_name)
os.system("ls")

options = {}
options['shape_evolution'] = 'random'
options['makemovie'] = 'none'
options['labels'] = 'unique'
options['subsize'] = 800 #controls the size of the shape (larger number is smaller)
#options['viewangle'] = [0,90] #down z axis
#options['viewangle'] = [90,0] #side view
#options['viewangle'] = [45,45] #3D view

answer = slml2info([model_file], options)

HTML(filename = 'index.html')
# Out:
# CellOrganizer v2.10 (MATLAB RO2019a)
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filename</h2>
# <p>/home/murphylab/cellorganizer/local/models/Module2A1.mat</p>
# <h2>Model name</h2>
# <p>Module2A1</p>
# <h2>Model ID</h2>
# <p>cc14d31e-c726-11ed-9c21-0242ac110002</p>
# <h2>Dimensionality</h2>
# <p>3D</p>
# <h2>Documentation</h2>
# <p>Fields and values present in the documentation structure</p><p>date</p><p>20-Mar-2023</p>
# <h2>Nuclear shape model information</h2>
# <p>Fields and values present in the submodel</p>
# <h2>Model Name</h2>
# <p>unset</p>
# <h2>ID</h2>
# <p>UNSET</p>
# <h2>Model Class</h2>
# <p>nuclear_membrane</p>
# <h2>Model Type</h2>
# <p>spharm_rpdm</p>
# <h2>Model Resolution</h2>
# <p>[0.392 0.392 0.4]</p>
# <h2>Cell shape model information</h2>
# <p>Fields and values present in the submodel</p>
# <h2>Model Name</h2>
# <p>unset</p>
# <h2>ID</h2>
# <p>UNSET</p>
# <h2>Model Class</h2>
# <p>cell_membrane</p>
# <h2>Model Type</h2>
# <p>spharm_rpdm</p>
# <h2>Model Resolution</h2>
# <p>[0.392 0.392 0.4]</p>
# <h2>Protein pattern model information</h2>
# <p>The model file does not contain an instance of the submodel</p>
# <h2>Dataset Information</h2>
# <body style= font-family:arial;>
# <table border="1"; bordercolor="#dddddd"; cellpadding="8"; cellspacing="0">
# <tr>
# <th>Cell Membrane File</th>
# <th>Nuclear Membrane File</th>
# <th>Parameter</th>
# <th>Preprocessing Status</th>
# </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell10_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell10_ch0_t1.tif</td>
# <td>param1.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell11_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell11_ch0_t1.tif</td>
# <td>param2.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell12_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell12_ch0_t1.tif</td>
# <td>param3.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell13_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell13_ch0_t1.tif</td>
# <td>param4.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell14_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell14_ch0_t1.tif</td>
# <td>param5.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell15_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell15_ch0_t1.tif</td>
# <td>param6.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell16_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell16_ch0_t1.tif</td>
# <td>param7.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell17_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell17_ch0_t1.tif</td>
# <td>param8.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell18_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell18_ch0_t1.tif</td>
# <td>param9.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# </table>
# <p></p>
# <h2>SPHARM-RPDM model quality</h2>
# <p>Cell:Hausdorff distances avg=1.1969, sd=0.11348, min=1.0885 [5], max=1.3981 [6]</p><p>Nuc:Hausdorff distances avg=0.98021, sd=0.040304, min=0.93489 [5], max=1.0675 [1]</p>
#
#
# <h2>Additional Figures</h2>
#
#
# </body>
# </html>

# %%
Image('show_shape_evolution.png')

# %%
Image('show_shape_space.png')

# %%
options['subsize'] = 200 #controls the size of the shape (larger number is smaller)
options['viewangle'] = [0,90] #down z axis
answer = slml2info([model_file], options)
#HTML(filename="index.html")
# Out:
# CellOrganizer v2.10 (MATLAB RO2019a)

# %%
Image('show_shape_evolution.png')

# %%
Image('show_shape_space.png')

# %%
os.chdir(outputdir)
model_name =  'Module2A2'
if not os.path.exists(model_name):
    os.makedirs(model_name)
os.chdir(model_name)
os.system("ls")
options['subsize'] = 200 #controls the size of the shape (larger number is smaller)

model_file = "/home/murphylab/cellorganizer/local/models/" +  model_name + ".mat"
# optionally, change to read the version of the model files in the results directory of Module 2A 
#model_file = "/home/murphylab/cellorganizer/local/results/Module2A/" +  model_name + ".mat"

answer = slml2info([model_file], options)
HTML(filename="index.html")
# Out:
# CellOrganizer v2.10 (MATLAB RO2019a)
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filename</h2>
# <p>/home/murphylab/cellorganizer/local/models/Module2A2.mat</p>
# <h2>Model name</h2>
# <p>Module2A2</p>
# <h2>Model ID</h2>
# <p>8906b19c-c72f-11ed-9c21-0242ac110002</p>
# <h2>Dimensionality</h2>
# <p>3D</p>
# <h2>Documentation</h2>
# <p>Fields and values present in the documentation structure</p><p>date</p><p>20-Mar-2023</p>
# <h2>Nuclear shape model information</h2>
# <p>Fields and values present in the submodel</p>
# <h2>Model Name</h2>
# <p>unset</p>
# <h2>ID</h2>
# <p>UNSET</p>
# <h2>Model Class</h2>
# <p>nuclear_membrane</p>
# <h2>Model Type</h2>
# <p>spharm_rpdm</p>
# <h2>Model Resolution</h2>
# <p>[0.392 0.392 0.4]</p>
# <h2>Cell shape model information</h2>
# <p>Fields and values present in the submodel</p>
# <h2>Model Name</h2>
# <p>unset</p>
# <h2>ID</h2>
# <p>UNSET</p>
# <h2>Model Class</h2>
# <p>cell_membrane</p>
# <h2>Model Type</h2>
# <p>spharm_rpdm</p>
# <h2>Model Resolution</h2>
# <p>[0.392 0.392 0.4]</p>
# <h2>Protein pattern model information</h2>
# <p>The model file does not contain an instance of the submodel</p>
# <h2>Dataset Information</h2>
# <body style= font-family:arial;>
# <table border="1"; bordercolor="#dddddd"; cellpadding="8"; cellspacing="0">
# <tr>
# <th>Cell Membrane File</th>
# <th>Nuclear Membrane File</th>
# <th>Parameter</th>
# <th>Preprocessing Status</th>
# </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell20_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell20_ch0_t1.tif</td>
# <td>param1.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell21_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell21_ch0_t1.tif</td>
# <td>param2.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell22_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell22_ch0_t1.tif</td>
# <td>param3.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell23_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell23_ch0_t1.tif</td>
# <td>param4.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell24_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell24_ch0_t1.tif</td>
# <td>param5.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell25_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell25_ch0_t1.tif</td>
# <td>param6.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell26_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell26_ch0_t1.tif</td>
# <td>param7.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell27_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell27_ch0_t1.tif</td>
# <td>param8.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell28_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell28_ch0_t1.tif</td>
# <td>param9.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# <tr>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell29_ch1_t1.tif</td>
# <td>/home/murphylab/cellorganizer/local/images/HeLa/3D/processed/LAM_cell29_ch0_t1.tif</td>
# <td>param10.mat</td>
# <td><font color="green">Accepted</font></td>
# % </tr>
# </table>
# <p></p>
# <h2>SPHARM-RPDM model quality</h2>
# <p>Cell:Hausdorff distances avg=1.2607, sd=0.11003, min=1.1087 [3], max=1.4929 [8]</p><p>Nuc:Hausdorff distances avg=1.0436, sd=0.058566, min=0.98 [10], max=1.1484 [3]</p>
#
#
# <h2>Additional Figures</h2>
#
#
# </body>
# </html>

# %%
Image('show_shape_evolution.png')

# %%
Image('show_shape_space.png')
