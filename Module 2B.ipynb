# %% [markdown]
# <h1> Module 2B</h1>

# %% [markdown]
# <h3> Part 1</h3>

# %%
from cellorganizer.tools import slml2info
import os
import urllib.request
import tarfile 
import os
from IPython.core.display import display, HTML, Image

folder_name = 'Module2B'
model_name = 'HeLa_3D_SPHARM_lamp2'
model_file = "/home/murphylab/cellorganizer/local/models/3D/SPHARM-RPDM/" +  model_name + ".mat"

topdir = "/home/murphylab/cellorganizer/local/results"
outputdir = topdir + "/" + folder_name
if not os.path.exists(topdir):
    os.makedirs(topdir)
os.chdir(topdir)
os.system("ls")
if not os.path.exists(outputdir):
    os.makedirs(outputdir)
os.chdir(outputdir)
os.system("ls")
if not os.path.exists(model_name):
    os.makedirs(model_name)
os.chdir(model_name)
os.system("ls")

options = {}
#options['shape_evolution'] = 'none'
options['labels'] = 'unique'
options['subsize'] = 800 #controls the size of the shape (larger number is smaller)
#options['viewangle'] = [0,90] #down z axis
#options['viewangle'] = [90,0] #side view
#options['viewangle'] = [45,45] #3D view

answer = slml2info([model_file], options)



HTML(filename = 'index.html')
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filename</h2>
# <p>/home/murphylab/cellorganizer/local/models/3D/SPHARM-RPDM/HeLa_3D_SPHARM_lamp2.mat</p>
# <h2>Model name</h2>
# <p>lamp2</p>
# <h2>Model ID</h2>
# <p>lamp2</p>
# <h2>Dimensionality</h2>
# <p>3D</p>
# <h2>Documentation</h2>
# <p>Fields and values present in the documentation structure</p><p>description</p><p>This model has been trained using demo2D05 from CellOrganizer</p><p>date</p><p>19-Sep-2018</p>
# <h2>Nuclear shape model information</h2>
# <p>Fields and values present in the submodel</p>
# <h2>Model Name</h2>
# <p>LAMP2</p>
# <h2>ID</h2>
# <p>UNSET</p>
# <h2>Model Class</h2>
# <p>framework</p>
# <h2>Model Type</h2>
# <p>spharm_rpdm</p>
# <h2>Model Resolution</h2>
# <p>[0.245 0.245 0.2]</p>
# <h2>Cell shape model information</h2>
# <p>Fields and values present in the submodel</p>
# <h2>Model Name</h2>
# <p></p>
# <h2>ID</h2>
# <p>UNSET</p>
# <h2>Model Class</h2>
# <p>framework</p>
# <h2>Model Type</h2>
# <p>spharm_rpdm</p>
# <h2>Model Resolution</h2>
# <p>[0.245 0.245 0.2]</p>
# <h2>Protein pattern model information</h2>
# <p>The model file does not contain an instance of the submodel</p>
# <h2>Additional Figures</h2>
#
# <figure>
# <a href="show_shape_evolution.png"><img src="show_shape_evolution_thumbnail.png" /></a>
# <figcaption>SPHARM-RPDM Cell Shape Model: Shape Evolution</figcaption>
# </figure>
#
#
# <figure>
# <a href="show_shape_space.png"><img src="show_shape_space_thumbnail.png" /></a>
# <figcaption>SPHARM-RPDM Cell Shape Model: Shape space</figcaption>
# </figure>
#
# </body>
# </html>

# %%
Image('show_shape_evolution.png')

# %%
Image('show_shape_space.png')

# %%
options['subsize'] = 200 #controls the size of the shape (larger number is smaller)
options['viewangle'] = [0,90] #down z axis
answer = slml2info([model_file], options)
#HTML(filename="index.html")

# %%
Image('show_shape_evolution.png')

# %%
Image('show_shape_space.png')

# %%
os.chdir(outputdir)
model_name =  'Module2A4'
if not os.path.exists(model_name):
    os.makedirs(model_name)
os.chdir(model_name)
os.system("ls")
options['subsize'] = 200 #controls the size of the shape (larger number is smaller)

model_file = "/home/murphylab/cellorganizer/local/models/3D/SPHARM-RPDM/" +  model_name + ".mat"
answer = slml2info([model_file], options)
HTML(filename="index.html")
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Filename</h2>
# <p>/home/murphylab/cellorganizer/local/models/3D/SPHARM-RPDM/Module2A4.mat</p>
# <h2>Model name</h2>
# <p>Module2A4</p>
# <h2>Model ID</h2>
# <p>6901AD9F-0369-4BE3-B0BE-DC40CF3C61C7</p>
# <h2>Dimensionality</h2>
# <p>3D</p>
# <h2>Documentation</h2>
# <p>Fields and values present in the documentation structure</p><p>date</p><p>23-Jun-2020</p>
# <h2>Nuclear shape model information</h2>
# <p>The model file does not contain an instance of the submodel</p>
# <h2>Cell shape model information</h2>
# <p>Fields and values present in the submodel</p>
# <h2>Model Name</h2>
# <p>unset</p>
# <h2>ID</h2>
# <p>UNSET</p>
# <h2>Model Class</h2>
# <p>cell_membrane</p>
# <h2>Model Type</h2>
# <p>spharm_rpdm</p>
# <h2>Model Resolution</h2>
# <p>[0.2 0.2 0.1]</p>
# <h2>Protein pattern model information</h2>
# <p>The model file does not contain an instance of the submodel</p>
# <h2>Dataset Information</h2>
# <body style= font-family:arial;>
# Dataset is composed of function handles. Ignoring request.
# <h2>Additional Figures</h2>
#
# <figure>
# <a href="show_shape_evolution.png"><img src="show_shape_evolution_thumbnail.png" /></a>
# <figcaption>SPHARM-RPDM Cell Shape Model: Shape Evolution</figcaption>
# </figure>
#
#
# <figure>
# <a href="show_shape_space.png"><img src="show_shape_space_thumbnail.png" /></a>
# <figcaption>SPHARM-RPDM Cell Shape Model: Shape space</figcaption>
# </figure>
#
# </body>
# </html>

# %%
Image('show_shape_evolution.png')

# %%
Image('show_shape_space.png')
